# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import cv2
import os

import udacityhelpers as udacity
from lanelines import *
import lanefinder

# %%
import lanespipeline 

from compgraph import CompGraph, CompGraphRunner
import nxpd
nxpd.nxpdParams['show'] = 'ipynb'

# %%
cg = lanespipeline.computational_graph
params = lanespipeline.parameters.copy()

finder, find_and_draw_lanes = lanefinder.create_objects(cg, params)

# %%
test_images = [ mpimg.imread( os.path.join('test_images', fname) ) for fname in os.listdir('test_images')]

# %%
visualize_test_images(test_images, proc_func=find_and_draw_lanes)

# %% [markdown]
# Result validation with Matplotlib lines:

# %%
plt.figure(figsize=(16, 16))
for i, im in enumerate(test_images):
    plt.subplot(3, 2, i+1)
    plt.imshow(im)
    left, right = finder.process(im)
    plot_line(left, color='r')
    plot_line(right, color='r')
